# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('odnb_onehot_correlations_3_1_18.csv')

# %%
df.iloc[:, 0:10]
# Out:
#                                              Unnamed: 0  baptized   married  \
# 0                                              baptized  1.000000  0.054826
# 1                                               married  0.054826  1.000000
# 2                                              gender_f -0.013856 -0.012565
# 3                                              gender_m  0.013856  0.012565
# 4                                            faith_Bah' -0.001756 -0.010759
# 5                                        faith_Buddhist -0.007453  0.003602
# 6                                        faith_Chistian -0.001756  0.002300
# 7                                       faith_Christian  0.052337 -0.050201
# 8                             faith_Christian Scientist -0.001756  0.002300
# 9                                    faith_Christianity -0.005826 -0.004185
# 10                                     faith_Christians -0.001756  0.002300
# ...

# %%
df = df.set_index('Unnamed: 0')
# Out:
# Unnamed: 0
# gender_m                                                                                                          -1.000000
# category_Armed Forces and Intelligence Services                                                                   -0.067188
# Block_stu                                                                                                         -0.063775
# category_Politics, Government, and Diplomacy                                                                      -0.051492
# category_Politics, Government, and Diplomacy; Religion and Belief                                                 -0.050730
# Block_tud                                                                                                         -0.047821
# category_Armed Forces and Intelligence Services; Politics, Government, and Diplomacy                              -0.046908
# ...

# %%
pd.set_option('display.max_rows', None)
df['Block_sha'].sort_values(ascending=False)
# Out:
# Unnamed: 0
# Block_sha                                                                                                                                                            1.000000
# Section_au7                                                                                                                                                          0.321257
# Section_au4                                                                                                                                                          0.314742
# Section_au2                                                                                                                                                          0.301298
# Section_au3                                                                                                                                                          0.274971
# ...
